# %%
import os 
import glob 
import datetime
import numpy as np
import pandas as pd

code = 'RB'

roll = 5
label = 30
test_start = '2023-01-01'
reduncy_rows = 50
fix = 513

part = '20250410_handmade'
dir = f'E:/dragon/GA_Shane/outputs/{part}'
os.chdir(dir)

# Tsfel
window_size = 10 
file_name_1 = glob.glob(os.path.join(dir, '*_output_axis.csv'))[0]
df = pd.read_csv(file_name_1)

file_name_2 = glob.glob(os.path.join(dir, f'*_output_axis_Label_{str(fix)}.csv'))[0]
df_label = pd.read_csv(file_name_2)

date = df['eob'] > '2023-01-01'    ##########  测试集开始日期，格式：xxxx-xx-xx     #############

roll = 5 ######## 窗口期

label = 30   ######## 如果标签9是26  8是27，7是28，6是29，5是30,15是20

date_df = df[date]

# %%
Train = len(df) - len(date_df) - 30     #######  减少30个，是为了给特征留出计算的空间
print('Train: ' + str(Train))

Test = len(date_df)
print('Test: ' + str(Test))
# Out:
# Train: 55650
# Test: 6355

# %%
file_80 = file_name_1 + '_tz80.csv'    ############ 80个特征过度文件 ############

file_400_Train = file_name_1 + "_tz80_Train_" + str(Train) + ".csv"    ############  训练集文件  #############

file_400_Test = file_name_1 + "_tz80_Test_" + str(Test) + ".csv"    #############  测试集文件 ############

file_400_Train_3 = file_name_1 + "_tz80_Test_" + str(Test) + "_PCA" + ".csv"    #############  测试集针对PCA降维文件 ############

file_Train = str(Train) + ".csv"
file_Test = str(Test) + ".csv"

# %%
file_name ='1_400.csv'   
file_temp = pd.read_csv(file_name)
###### 复制第0行N遍 ######
temp_df = file_temp.iloc[0]
for t in range(Train-1): 
        file_temp.loc[file_temp.shape[0]] = temp_df
file_temp.to_csv(str(Train) + ".csv",index = False)



file_name ='1_400.csv'   
file_temp = pd.read_csv(file_name)
###### 复制第0行N遍 ######
temp_df = file_temp.iloc[0]
for t in range(Test-1): 
        file_temp.loc[file_temp.shape[0]] = temp_df
file_temp.to_csv(str(Test) + ".csv",index = False)


#######################################################################################################


df['open'] = df['open'].astype('float64')
df['close'] = df['close'].astype('float64')
df['high'] = df['high'].astype('float64')
df['low'] = df['low'].astype('float64')


open1 = df['open']
close = df['close']
high = df['high']
low = df['low']


eob = df['eob']
datelist = pd.to_datetime(eob[5:])

########################################################################################


logopen1_1 = (np.log(np.array(open1[1:]))-np.log(np.array(open1[:-1])))[4:]
logopen1_2 = (np.log(np.array(open1[1:]))-np.log(np.array(close[:-1])))[4:]
logopen1_3 = (np.log(np.array(open1[1:]))-np.log(np.array(high[:-1])))[4:]
logopen1_4 = (np.log(np.array(open1[1:]))-np.log(np.array(low[:-1])))[4:]

logopen2_1 = np.log(np.array(open1[2:]))-np.log(np.array(open1[:-2]))
logopen2_2 = np.log(np.array(open1[2:]))-np.log(np.array(close[:-2]))
logopen2_3 = np.log(np.array(open1[2:]))-np.log(np.array(high[:-2]))
logopen2_4 = np.log(np.array(open1[2:]))-np.log(np.array(low[:-2]))

logopen3_1 = np.log(np.array(open1[3:]))-np.log(np.array(open1[:-3]))
logopen3_2 = np.log(np.array(open1[3:]))-np.log(np.array(close[:-3]))
logopen3_3 = np.log(np.array(open1[3:]))-np.log(np.array(high[:-3]))
logopen3_4 = np.log(np.array(open1[3:]))-np.log(np.array(low[:-3]))

logopen4_1 = np.log(np.array(open1[4:]))-np.log(np.array(open1[:-4]))
logopen4_2 = np.log(np.array(open1[4:]))-np.log(np.array(close[:-4]))
logopen4_3 = np.log(np.array(open1[4:]))-np.log(np.array(high[:-4]))
logopen4_4 = np.log(np.array(open1[4:]))-np.log(np.array(low[:-4]))

logopen5_1 = np.log(np.array(open1[5:]))-np.log(np.array(open1[:-5]))
logopen5_2 = np.log(np.array(open1[5:]))-np.log(np.array(close[:-5]))
logopen5_3 = np.log(np.array(open1[5:]))-np.log(np.array(high[:-5]))
logopen5_4 = np.log(np.array(open1[5:]))-np.log(np.array(low[:-5]))



logclose1_1 = (np.log(np.array(close[1:]))-np.log(np.array(open1[:-1])))[4:]
logclose1_2 = (np.log(np.array(close[1:]))-np.log(np.array(close[:-1])))[4:]
logclose1_3 = (np.log(np.array(close[1:]))-np.log(np.array(high[:-1])))[4:]
logclose1_4 = (np.log(np.array(close[1:]))-np.log(np.array(low[:-1])))[4:]            

logclose2_1 = np.log(np.array(close[2:]))-np.log(np.array(open1[:-2]))
logclose2_2 = np.log(np.array(close[2:]))-np.log(np.array(close[:-2]))
logclose2_3 = np.log(np.array(close[2:]))-np.log(np.array(high[:-2]))
logclose2_4 = np.log(np.array(close[2:]))-np.log(np.array(low[:-2]))

logclose3_1 = np.log(np.array(close[3:]))-np.log(np.array(open1[:-3]))
logclose3_2 = np.log(np.array(close[3:]))-np.log(np.array(close[:-3]))
logclose3_3 = np.log(np.array(close[3:]))-np.log(np.array(high[:-3]))
logclose3_4 = np.log(np.array(close[3:]))-np.log(np.array(low[:-3]))

logclose4_1 = np.log(np.array(close[4:]))-np.log(np.array(open1[:-4]))
logclose4_2 = np.log(np.array(close[4:]))-np.log(np.array(close[:-4]))
logclose4_3 = np.log(np.array(close[4:]))-np.log(np.array(high[:-4]))
logclose4_4 = np.log(np.array(close[4:]))-np.log(np.array(low[:-4]))

logclose5_1 = np.log(np.array(close[5:]))-np.log(np.array(open1[:-5]))
logclose5_2 = np.log(np.array(close[5:]))-np.log(np.array(close[:-5]))
logclose5_3 = np.log(np.array(close[5:]))-np.log(np.array(high[:-5]))
logclose5_4 = np.log(np.array(close[5:]))-np.log(np.array(low[:-5]))



loghigh1_1 = (np.log(np.array(high[1:]))-np.log(np.array(open1[:-1])))[4:]
loghigh1_2 = (np.log(np.array(high[1:]))-np.log(np.array(close[:-1])))[4:]
loghigh1_3 = (np.log(np.array(high[1:]))-np.log(np.array(high[:-1])))[4:]
loghigh1_4 = (np.log(np.array(high[1:]))-np.log(np.array(low[:-1])))[4:]

loghigh2_1 = np.log(np.array(high[2:]))-np.log(np.array(open1[:-2]))
loghigh2_2 = np.log(np.array(high[2:]))-np.log(np.array(close[:-2]))
loghigh2_3 = np.log(np.array(high[2:]))-np.log(np.array(high[:-2]))
loghigh2_4 = np.log(np.array(high[2:]))-np.log(np.array(low[:-2]))

loghigh3_1 = np.log(np.array(high[3:]))-np.log(np.array(open1[:-3]))
loghigh3_2 = np.log(np.array(high[3:]))-np.log(np.array(close[:-3]))
loghigh3_3 = np.log(np.array(high[3:]))-np.log(np.array(high[:-3]))
loghigh3_4 = np.log(np.array(high[3:]))-np.log(np.array(low[:-3]))

loghigh4_1 = np.log(np.array(high[4:]))-np.log(np.array(open1[:-4]))
loghigh4_2 = np.log(np.array(high[4:]))-np.log(np.array(close[:-4]))
loghigh4_3 = np.log(np.array(high[4:]))-np.log(np.array(high[:-4]))
loghigh4_4 = np.log(np.array(high[4:]))-np.log(np.array(low[:-4]))

loghigh5_1 = np.log(np.array(high[5:]))-np.log(np.array(open1[:-5]))
loghigh5_2 = np.log(np.array(high[5:]))-np.log(np.array(close[:-5]))
loghigh5_3 = np.log(np.array(high[5:]))-np.log(np.array(high[:-5]))
loghigh5_4 = np.log(np.array(high[5:]))-np.log(np.array(low[:-5]))



loglow1_1 = (np.log(np.array(low[1:]))-np.log(np.array(open1[:-1])))[4:]
loglow1_2 = (np.log(np.array(low[1:]))-np.log(np.array(close[:-1])))[4:]
loglow1_3 = (np.log(np.array(low[1:]))-np.log(np.array(high[:-1])))[4:]
loglow1_4 = (np.log(np.array(low[1:]))-np.log(np.array(low[:-1])))[4:]

loglow2_1 = np.log(np.array(low[2:]))-np.log(np.array(open1[:-2]))
loglow2_2 = np.log(np.array(low[2:]))-np.log(np.array(close[:-2]))
loglow2_3 = np.log(np.array(low[2:]))-np.log(np.array(high[:-2]))
loglow2_4 = np.log(np.array(low[2:]))-np.log(np.array(low[:-2]))

loglow3_1 = np.log(np.array(low[3:]))-np.log(np.array(open1[:-3]))
loglow3_2 = np.log(np.array(low[3:]))-np.log(np.array(close[:-3]))
loglow3_3 = np.log(np.array(low[3:]))-np.log(np.array(high[:-3]))
loglow3_4 = np.log(np.array(low[3:]))-np.log(np.array(low[:-3]))

loglow4_1 = np.log(np.array(low[4:]))-np.log(np.array(open1[:-4]))
loglow4_2 = np.log(np.array(low[4:]))-np.log(np.array(close[:-4]))
loglow4_3 = np.log(np.array(low[4:]))-np.log(np.array(high[:-4]))
loglow4_4 = np.log(np.array(low[4:]))-np.log(np.array(low[:-4]))

loglow5_1 = np.log(np.array(low[5:]))-np.log(np.array(open1[:-5]))
loglow5_2 = np.log(np.array(low[5:]))-np.log(np.array(close[:-5]))
loglow5_3 = np.log(np.array(low[5:]))-np.log(np.array(high[:-5]))
loglow5_4 = np.log(np.array(low[5:]))-np.log(np.array(low[:-5]))



##################################################################################


close2 = df['close'][5:]
data = pd.DataFrame(columns=['close',
                             'logopen1_1','logopen1_2','logopen1_3','logopen1_4',
                             'logopen2_1','logopen2_2','logopen2_3','logopen2_4',
                             'logopen3_1','logopen3_2','logopen3_3','logopen3_4',
                             'logopen4_1','logopen4_2','logopen4_3','logopen4_4',
                             'logopen5_1','logopen5_2','logopen5_3','logopen5_4',
                             'logclose1_1','logclose1_2','logclose1_3','logclose1_4',
                             'logclose2_1','logclose2_2','logclose2_3','logclose2_4',
                             'logclose3_1','logclose3_2','logclose3_3','logclose3_4',
                             'logclose4_1','logclose4_2','logclose4_3','logclose4_4',
                             'logclose5_1','logclose5_2','logclose5_3','logclose5_4',
                             'loghigh1_1','loghigh1_2','loghigh1_3','loghigh1_4',
                             'loghigh2_1','loghigh2_2','loghigh2_3','loghigh2_4',
                             'loghigh3_1','loghigh3_2','loghigh3_3','loghigh3_4',
                             'loghigh4_1','loghigh4_2','loghigh4_3','loghigh4_4',
                             'loghigh5_1','loghigh5_2','loghigh5_3','loghigh5_4',
                             'loglow1_1','loglow1_2','loglow1_3','loglow1_4',
                             'loglow2_1','loglow2_2','loglow2_3','loglow2_4',
                             'loglow3_1','loglow3_2','loglow3_3','loglow3_4',
                             'loglow4_1','loglow4_2','loglow4_3','loglow4_4',
                             'loglow5_1','loglow5_2','loglow5_3','loglow5_4'])
                             
    
data['close'] = close2
data['logopen1_1'] = logopen1_1
data['logopen1_2'] = logopen1_2
data['logopen1_3'] = logopen1_3
data['logopen1_4'] = logopen1_4

data['logopen2_1'] = logopen2_1[3:]
data['logopen2_2'] = logopen2_2[3:]
data['logopen2_3'] = logopen2_3[3:]
data['logopen2_4'] = logopen2_4[3:]

data['logopen3_1'] = logopen3_1[2:]
data['logopen3_2'] = logopen3_2[2:]
data['logopen3_3'] = logopen3_3[2:]
data['logopen3_4'] = logopen3_4[2:]

data['logopen4_1'] = logopen4_1[1:]
data['logopen4_2'] = logopen4_2[1:]
data['logopen4_3'] = logopen4_3[1:]
data['logopen4_4'] = logopen4_4[1:]

data['logopen5_1'] = logopen5_1
data['logopen5_2'] = logopen5_2
data['logopen5_3'] = logopen5_3
data['logopen5_4'] = logopen5_4


data['logclose1_1'] = logclose1_1
data['logclose1_2'] = logclose1_2
data['logclose1_3'] = logclose1_3
data['logclose1_4'] = logclose1_4

data['logclose2_1'] = logclose2_1[3:]
data['logclose2_2'] = logclose2_2[3:]
data['logclose2_3'] = logclose2_3[3:]
data['logclose2_4'] = logclose2_4[3:]

data['logclose3_1'] = logclose3_1[2:]
data['logclose3_2'] = logclose3_2[2:]
data['logclose3_3'] = logclose3_3[2:]
data['logclose3_4'] = logclose3_4[2:]

data['logclose4_1'] = logclose4_1[1:]
data['logclose4_2'] = logclose4_2[1:]
data['logclose4_3'] = logclose4_3[1:]
data['logclose4_4'] = logclose4_4[1:]

data['logclose5_1'] = logclose5_1
data['logclose5_2'] = logclose5_2
data['logclose5_3'] = logclose5_3
data['logclose5_4'] = logclose5_4

data['loghigh1_1'] = loghigh1_1
data['loghigh1_2'] = loghigh1_2
data['loghigh1_3'] = loghigh1_3
data['loghigh1_4'] = loghigh1_4

data['loghigh2_1'] = loghigh2_1[3:]
data['loghigh2_2'] = loghigh2_2[3:]
data['loghigh2_3'] = loghigh2_3[3:]
data['loghigh2_4'] = loghigh2_4[3:]

data['loghigh3_1'] = loghigh3_1[2:]
data['loghigh3_2'] = loghigh3_2[2:]
data['loghigh3_3'] = loghigh3_3[2:]
data['loghigh3_4'] = loghigh3_4[2:]

data['loghigh4_1'] = loghigh4_1[1:]
data['loghigh4_2'] = loghigh4_2[1:]
data['loghigh4_3'] = loghigh4_3[1:]
data['loghigh4_4'] = loghigh4_4[1:]

data['loghigh5_1'] = loghigh5_1
data['loghigh5_2'] = loghigh5_2
data['loghigh5_3'] = loghigh5_3
data['loghigh5_4'] = loghigh5_4

data['loglow1_1'] = loglow1_1
data['loglow1_2'] = loglow1_2
data['loglow1_3'] = loglow1_3
data['loglow1_4'] = loglow1_4

data['loglow2_1'] = loglow2_1[3:]
data['loglow2_2'] = loglow2_2[3:]
data['loglow2_3'] = loglow2_3[3:]
data['loglow2_4'] = loglow2_4[3:]

data['loglow3_1'] = loglow3_1[2:]
data['loglow3_2'] = loglow3_2[2:]
data['loglow3_3'] = loglow3_3[2:]
data['loglow3_4'] = loglow3_4[2:]

data['loglow4_1'] = loglow4_1[1:]
data['loglow4_2'] = loglow4_2[1:]
data['loglow4_3'] = loglow4_3[1:]
data['loglow4_4'] = loglow4_4[1:]

data['loglow5_1'] = loglow5_1
data['loglow5_2'] = loglow5_2
data['loglow5_3'] = loglow5_3
data['loglow5_4'] = loglow5_4
    
    

data.to_csv(file_80,index = False)

#################################################################################

file_name = file_80
df1 = pd.read_csv(file_name)


    
a1 = df1['logopen1_1']
a2 = df1['logopen1_2']
a3 = df1['logopen1_3']
a4 = df1['logopen1_4']

a5 = df1['logopen2_1']
a6 = df1['logopen2_2']
a7 = df1['logopen2_3']
a8 = df1['logopen2_4']

a9 = df1['logopen3_1']
a10 = df1['logopen3_2']
a11 = df1['logopen3_3']
a12 = df1['logopen3_4'] 

a13 = df1['logopen4_1']
a14 = df1['logopen4_2']
a15 = df1['logopen4_3']
a16 = df1['logopen4_4']

a17 = df1['logopen5_1'] 
a18 = df1['logopen5_2'] 
a19 = df1['logopen5_3'] 
a20 = df1['logopen5_4'] 

a21 = df1['logclose1_1'] 
a22 = df1['logclose1_2'] 
a23 = df1['logclose1_3'] 
a24 = df1['logclose1_4'] 

a25 = df1['logclose2_1'] 
a26 = df1['logclose2_2'] 
a27 = df1['logclose2_3'] 
a28 = df1['logclose2_4'] 

a29 = df1['logclose3_1'] 
a30 = df1['logclose3_2'] 
a31 = df1['logclose3_3'] 
a32 = df1['logclose3_4'] 

a33 = df1['logclose4_1'] 
a34 = df1['logclose4_2'] 
a35 = df1['logclose4_3'] 
a36 = df1['logclose4_4'] 

a37 = df1['logclose5_1'] 
a38 = df1['logclose5_2'] 
a39 = df1['logclose5_3'] 
a40 = df1['logclose5_4'] 

a41 = df1['loghigh1_1'] 
a42 = df1['loghigh1_2'] 
a43 = df1['loghigh1_3'] 
a44 = df1['loghigh1_4'] 

a45 = df1['loghigh2_1'] 
a46 = df1['loghigh2_2'] 
a47 = df1['loghigh2_3'] 
a48 = df1['loghigh2_4'] 

a49 = df1['loghigh3_1'] 
a50 = df1['loghigh3_2'] 
a51 = df1['loghigh3_3']
a52 = df1['loghigh3_4'] 

a53 = df1['loghigh4_1'] 
a54 = df1['loghigh4_2'] 
a55 = df1['loghigh4_3'] 
a56 = df1['loghigh4_4'] 

a57 = df1['loghigh5_1'] 
a58 = df1['loghigh5_2'] 
a59 = df1['loghigh5_3'] 
a60 = df1['loghigh5_4'] 

a61 = df1['loglow1_1'] 
a62 = df1['loglow1_2'] 
a63 = df1['loglow1_3'] 
a64 = df1['loglow1_4'] 

a65 = df1['loglow2_1'] 
a66 = df1['loglow2_2'] 
a67 = df1['loglow2_3'] 
a68 = df1['loglow2_4'] 

a69 = df1['loglow3_1']
a70 = df1['loglow3_2'] 
a71 = df1['loglow3_3'] 
a72 = df1['loglow3_4'] 

a73 = df1['loglow4_1'] 
a74 = df1['loglow4_2'] 
a75 = df1['loglow4_3'] 
a76 = df1['loglow4_4'] 

a77 = df1['loglow5_1'] 
a78 = df1['loglow5_2']
a79 = df1['loglow5_3'] 
a80 = df1['loglow5_4'] 

    
file_name = file_Train
df2 = pd.read_csv(file_name)


# 5个80个特征，共400列 

long = Train + 30


a = 0
b = 1
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a1[j-i]
        b = b+80
    a = a+1
    b = 1

    
a = 0
b = 2
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a2[j-i]
        b = b+80
    a = a+1
    b = 2


a = 0
b = 3
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a3[j-i]
        b = b+80
    a = a+1
    b = 3
    
    
a = 0
b = 4
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a4[j-i]
        b = b+80
    a = a+1
    b = 4

a = 0
b = 5
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a5[j-i]
        b = b+80
    a = a+1
    b = 5
    
a = 0
b = 6
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a6[j-i]
        b = b+80
    a = a+1
    b = 6

a = 0
b = 7
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a7[j-i]
        b = b+80
    a = a+1
    b = 7
    
a = 0
b = 8
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a8[j-i]
        b = b+80
    a = a+1
    b = 8
    

a = 0
b = 9
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a9[j-i]
        b = b+80
    a = a+1
    b = 9
    
a = 0
b = 10
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a10[j-i]
        b = b+80
    a = a+1
    b = 10

a = 0
b = 11
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a11[j-i]
        b = b+80
    a = a+1
    b = 11
    
    
a = 0
b = 12
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a12[j-i]
        b = b+80
    a = a+1
    b = 12
    
a = 0
b = 13
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a13[j-i]
        b = b+80
    a = a+1
    b = 13
    
    
a = 0
b = 14
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a14[j-i]
        b = b+80
    a = a+1
    b = 14
    
    
    
a = 0
b = 15
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a15[j-i]
        b = b+80
    a = a+1
    b = 15
    

a = 0
b = 16
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a16[j-i]
        b = b+80
    a = a+1
    b = 16

    
a = 0
b = 17
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a17[j-i]
        b = b+80
    a = a+1
    b = 17


a = 0
b = 18
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a18[j-i]
        b = b+80
    a = a+1
    b = 18
    
    
a = 0
b = 19
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a19[j-i]
        b = b+80
    a = a+1
    b = 19

a = 0
b = 20
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a20[j-i]
        b = b+80
    a = a+1
    b = 20
    
a = 0
b = 21
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a21[j-i]
        b = b+80
    a = a+1
    b = 21

a = 0
b = 22
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a22[j-i]
        b = b+80
    a = a+1
    b = 22
    
a = 0
b = 23
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a23[j-i]
        b = b+80
    a = a+1
    b = 23
    

a = 0
b = 24
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a24[j-i]
        b = b+80
    a = a+1
    b = 24
    
a = 0
b = 25
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a25[j-i]
        b = b+80
    a = a+1
    b = 25

a = 0
b = 26
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a26[j-i]
        b = b+80
    a = a+1
    b = 26
    
    
a = 0
b = 27
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a27[j-i]
        b = b+80
    a = a+1
    b = 27
    
a = 0
b = 28
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a28[j-i]
        b = b+80
    a = a+1
    b = 28
    
    
a = 0
b = 29
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a29[j-i]
        b = b+80
    a = a+1
    b = 29
    
    
    
a = 0
b = 30
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a30[j-i]
        b = b+80
    a = a+1
    b = 30
    
    

a = 0
b = 31
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a31[j-i]
        b = b+80
    a = a+1
    b = 31

    
a = 0
b = 32
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a32[j-i]
        b = b+80
    a = a+1
    b = 32


a = 0
b = 33
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a33[j-i]
        b = b+80
    a = a+1
    b = 33
    
    
a = 0
b = 34
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a34[j-i]
        b = b+80
    a = a+1
    b = 34

a = 0
b = 35
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a35[j-i]
        b = b+80
    a = a+1
    b = 35
    
a = 0
b = 36
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a36[j-i]
        b = b+80
    a = a+1
    b = 36

a = 0
b = 37
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a37[j-i]
        b = b+80
    a = a+1
    b = 37
    
a = 0
b = 38
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a38[j-i]
        b = b+80
    a = a+1
    b = 38
    

a = 0
b = 39
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a39[j-i]
        b = b+80
    a = a+1
    b = 39
    
a = 0
b = 40
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a40[j-i]
        b = b+80
    a = a+1
    b = 40

a = 0
b = 41
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a41[j-i]
        b = b+80
    a = a+1
    b = 41
    
    
a = 0
b = 42
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a42[j-i]
        b = b+80
    a = a+1
    b = 42
    
a = 0
b = 43
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a43[j-i]
        b = b+80
    a = a+1
    b = 43
    
    
a = 0
b = 44
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a44[j-i]
        b = b+80
    a = a+1
    b = 44
    
    
    
a = 0
b = 45
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a45[j-i]
        b = b+80
    a = a+1
    b = 45
    

a = 0
b = 46
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a46[j-i]
        b = b+80
    a = a+1
    b = 46

    
a = 0
b = 47
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a47[j-i]
        b = b+80
    a = a+1
    b = 47


a = 0
b = 48
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a48[j-i]
        b = b+80
    a = a+1
    b = 48
    
    
a = 0
b = 49
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a49[j-i]
        b = b+80
    a = a+1
    b = 49

a = 0
b = 50
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a50[j-i]
        b = b+80
    a = a+1
    b = 50
    
a = 0
b = 51
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a51[j-i]
        b = b+80
    a = a+1
    b = 51

a = 0
b = 52
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a52[j-i]
        b = b+80
    a = a+1
    b = 52
    
a = 0
b = 53
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a53[j-i]
        b = b+80
    a = a+1
    b = 53
    

a = 0
b = 54
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a54[j-i]
        b = b+80
    a = a+1
    b = 54
    
a = 0
b = 55
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a55[j-i]
        b = b+80
    a = a+1
    b = 55

a = 0
b = 56
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a56[j-i]
        b = b+80
    a = a+1
    b = 56
    
    
a = 0
b = 57
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a57[j-i]
        b = b+80
    a = a+1
    b = 57
    
a = 0
b = 58
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a58[j-i]
        b = b+80
    a = a+1
    b = 58
    
    
a = 0
b = 59
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a59[j-i]
        b = b+80
    a = a+1
    b = 59
    
    
    
a = 0
b = 60
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a60[j-i]
        b = b+80
    a = a+1
    b = 60
    

a = 0
b = 61
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a61[j-i]
        b = b+80
    a = a+1
    b = 61

    
a = 0
b = 62
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a62[j-i]
        b = b+80
    a = a+1
    b = 62


a = 0
b = 63
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a63[j-i]
        b = b+80
    a = a+1
    b = 63
    
    
a = 0
b = 64
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a64[j-i]
        b = b+80
    a = a+1
    b = 64

a = 0
b = 65
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a65[j-i]
        b = b+80
    a = a+1
    b = 65

    
a = 0
b = 66
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a66[j-i]
        b = b+80
    a = a+1
    b = 66

a = 0
b = 67
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a67[j-i]
        b = b+80
    a = a+1
    b = 67
    
a = 0
b = 68
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a68[j-i]
        b = b+80
    a = a+1
    b = 68
    

a = 0
b = 69
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a69[j-i]
        b = b+80
    a = a+1
    b = 69
    
a = 0
b = 70
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a70[j-i]
        b = b+80
    a = a+1
    b = 70

a = 0
b = 71
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a71[j-i]
        b = b+80
    a = a+1
    b = 71
    
    
a = 0
b = 72
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a72[j-i]
        b = b+80
    a = a+1
    b = 72
    
a = 0
b = 73
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a73[j-i]
        b = b+80
    a = a+1
    b = 73
    
    
a = 0
b = 74
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a74[j-i]
        b = b+80
    a = a+1
    b = 74
    
    
    
a = 0
b = 75
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a75[j-i]
        b = b+80
    a = a+1
    b = 75
    

a = 0
b = 76
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a76[j-i]
        b = b+80
    a = a+1
    b = 76

    
a = 0
b = 77
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a77[j-i]
        b = b+80
    a = a+1
    b = 77


a = 0
b = 78
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a78[j-i]
        b = b+80
    a = a+1
    b = 78
    
    
a = 0
b = 79
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a79[j-i]
        b = b+80
    a = a+1
    b = 79

a = 0
b = 80
for j in range(30,long):   
    for i in range(roll):
        df2.iloc[a,b]=a80[j-i]
        b = b+80
    a = a+1
    b = 80
    
    
    
df2.to_csv(file_400_Train,index = False)
print('Train file OK')
##############################################################################



file_name = file_80
df1 = pd.read_csv(file_name)


    
a1 = df1['logopen1_1']
a2 = df1['logopen1_2']
a3 = df1['logopen1_3']
a4 = df1['logopen1_4']

a5 = df1['logopen2_1']
a6 = df1['logopen2_2']
a7 = df1['logopen2_3']
a8 = df1['logopen2_4']

a9 = df1['logopen3_1']
a10 = df1['logopen3_2']
a11 = df1['logopen3_3']
a12 = df1['logopen3_4'] 

a13 = df1['logopen4_1']
a14 = df1['logopen4_2']
a15 = df1['logopen4_3']
a16 = df1['logopen4_4']

a17 = df1['logopen5_1'] 
a18 = df1['logopen5_2'] 
a19 = df1['logopen5_3'] 
a20 = df1['logopen5_4'] 

a21 = df1['logclose1_1'] 
a22 = df1['logclose1_2'] 
a23 = df1['logclose1_3'] 
a24 = df1['logclose1_4'] 

a25 = df1['logclose2_1'] 
a26 = df1['logclose2_2'] 
a27 = df1['logclose2_3'] 
a28 = df1['logclose2_4'] 

a29 = df1['logclose3_1'] 
a30 = df1['logclose3_2'] 
a31 = df1['logclose3_3'] 
a32 = df1['logclose3_4'] 

a33 = df1['logclose4_1'] 
a34 = df1['logclose4_2'] 
a35 = df1['logclose4_3'] 
a36 = df1['logclose4_4'] 

a37 = df1['logclose5_1'] 
a38 = df1['logclose5_2'] 
a39 = df1['logclose5_3'] 
a40 = df1['logclose5_4'] 

a41 = df1['loghigh1_1'] 
a42 = df1['loghigh1_2'] 
a43 = df1['loghigh1_3'] 
a44 = df1['loghigh1_4'] 

a45 = df1['loghigh2_1'] 
a46 = df1['loghigh2_2'] 
a47 = df1['loghigh2_3'] 
a48 = df1['loghigh2_4'] 

a49 = df1['loghigh3_1'] 
a50 = df1['loghigh3_2'] 
a51 = df1['loghigh3_3']
a52 = df1['loghigh3_4'] 

a53 = df1['loghigh4_1'] 
a54 = df1['loghigh4_2'] 
a55 = df1['loghigh4_3'] 
a56 = df1['loghigh4_4'] 

a57 = df1['loghigh5_1'] 
a58 = df1['loghigh5_2'] 
a59 = df1['loghigh5_3'] 
a60 = df1['loghigh5_4'] 

a61 = df1['loglow1_1'] 
a62 = df1['loglow1_2'] 
a63 = df1['loglow1_3'] 
a64 = df1['loglow1_4'] 

a65 = df1['loglow2_1'] 
a66 = df1['loglow2_2'] 
a67 = df1['loglow2_3'] 
a68 = df1['loglow2_4'] 

a69 = df1['loglow3_1']
a70 = df1['loglow3_2'] 
a71 = df1['loglow3_3'] 
a72 = df1['loglow3_4'] 

a73 = df1['loglow4_1'] 
a74 = df1['loglow4_2'] 
a75 = df1['loglow4_3'] 
a76 = df1['loglow4_4'] 

a77 = df1['loglow5_1'] 
a78 = df1['loglow5_2']
a79 = df1['loglow5_3'] 
a80 = df1['loglow5_4'] 

    
file_name = file_Test
df2 = pd.read_csv(file_name)




long = len(df1)-1
short = long - Test


a = 0
b = 1
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a1[j-i]
        b = b+80
    a = a+1
    b = 1

    
a = 0
b = 2
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a2[j-i]
        b = b+80
    a = a+1
    b = 2


a = 0
b = 3
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a3[j-i]
        b = b+80
    a = a+1
    b = 3
    
    
a = 0
b = 4
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a4[j-i]
        b = b+80
    a = a+1
    b = 4

a = 0
b = 5
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a5[j-i]
        b = b+80
    a = a+1
    b = 5
    
a = 0
b = 6
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a6[j-i]
        b = b+80
    a = a+1
    b = 6

a = 0
b = 7
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a7[j-i]
        b = b+80
    a = a+1
    b = 7
    
a = 0
b = 8
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a8[j-i]
        b = b+80
    a = a+1
    b = 8
    

a = 0
b = 9
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a9[j-i]
        b = b+80
    a = a+1
    b = 9
    
a = 0
b = 10
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a10[j-i]
        b = b+80
    a = a+1
    b = 10

a = 0
b = 11
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a11[j-i]
        b = b+80
    a = a+1
    b = 11
    
    
a = 0
b = 12
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a12[j-i]
        b = b+80
    a = a+1
    b = 12
    
a = 0
b = 13
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a13[j-i]
        b = b+80
    a = a+1
    b = 13
    
    
a = 0
b = 14
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a14[j-i]
        b = b+80
    a = a+1
    b = 14
    
    
    
a = 0
b = 15
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a15[j-i]
        b = b+80
    a = a+1
    b = 15
    

a = 0
b = 16
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a16[j-i]
        b = b+80
    a = a+1
    b = 16

    
a = 0
b = 17
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a17[j-i]
        b = b+80
    a = a+1
    b = 17


a = 0
b = 18
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a18[j-i]
        b = b+80
    a = a+1
    b = 18
    
    
a = 0
b = 19
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a19[j-i]
        b = b+80
    a = a+1
    b = 19

a = 0
b = 20
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a20[j-i]
        b = b+80
    a = a+1
    b = 20
    
a = 0
b = 21
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a21[j-i]
        b = b+80
    a = a+1
    b = 21

a = 0
b = 22
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a22[j-i]
        b = b+80
    a = a+1
    b = 22
    
a = 0
b = 23
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a23[j-i]
        b = b+80
    a = a+1
    b = 23
    

a = 0
b = 24
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a24[j-i]
        b = b+80
    a = a+1
    b = 24
    
a = 0
b = 25
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a25[j-i]
        b = b+80
    a = a+1
    b = 25

a = 0
b = 26
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a26[j-i]
        b = b+80
    a = a+1
    b = 26
    
    
a = 0
b = 27
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a27[j-i]
        b = b+80
    a = a+1
    b = 27
    
a = 0
b = 28
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a28[j-i]
        b = b+80
    a = a+1
    b = 28
    
    
a = 0
b = 29
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a29[j-i]
        b = b+80
    a = a+1
    b = 29
    
    
    
a = 0
b = 30
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a30[j-i]
        b = b+80
    a = a+1
    b = 30
    
    

a = 0
b = 31
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a31[j-i]
        b = b+80
    a = a+1
    b = 31

    
a = 0
b = 32
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a32[j-i]
        b = b+80
    a = a+1
    b = 32


a = 0
b = 33
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a33[j-i]
        b = b+80
    a = a+1
    b = 33
    
    
a = 0
b = 34
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a34[j-i]
        b = b+80
    a = a+1
    b = 34

a = 0
b = 35
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a35[j-i]
        b = b+80
    a = a+1
    b = 35
    
a = 0
b = 36
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a36[j-i]
        b = b+80
    a = a+1
    b = 36

a = 0
b = 37
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a37[j-i]
        b = b+80
    a = a+1
    b = 37
    
a = 0
b = 38
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a38[j-i]
        b = b+80
    a = a+1
    b = 38
    

a = 0
b = 39
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a39[j-i]
        b = b+80
    a = a+1
    b = 39
    
a = 0
b = 40
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a40[j-i]
        b = b+80
    a = a+1
    b = 40

a = 0
b = 41
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a41[j-i]
        b = b+80
    a = a+1
    b = 41
    
    
a = 0
b = 42
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a42[j-i]
        b = b+80
    a = a+1
    b = 42
    
a = 0
b = 43
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a43[j-i]
        b = b+80
    a = a+1
    b = 43
    
    
a = 0
b = 44
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a44[j-i]
        b = b+80
    a = a+1
    b = 44
    
    
    
a = 0
b = 45
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a45[j-i]
        b = b+80
    a = a+1
    b = 45
    

a = 0
b = 46
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a46[j-i]
        b = b+80
    a = a+1
    b = 46

    
a = 0
b = 47
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a47[j-i]
        b = b+80
    a = a+1
    b = 47


a = 0
b = 48
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a48[j-i]
        b = b+80
    a = a+1
    b = 48
    
    
a = 0
b = 49
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a49[j-i]
        b = b+80
    a = a+1
    b = 49

a = 0
b = 50
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a50[j-i]
        b = b+80
    a = a+1
    b = 50
    
a = 0
b = 51
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a51[j-i]
        b = b+80
    a = a+1
    b = 51

a = 0
b = 52
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a52[j-i]
        b = b+80
    a = a+1
    b = 52
    
a = 0
b = 53
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a53[j-i]
        b = b+80
    a = a+1
    b = 53
    

a = 0
b = 54
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a54[j-i]
        b = b+80
    a = a+1
    b = 54
    
a = 0
b = 55
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a55[j-i]
        b = b+80
    a = a+1
    b = 55

a = 0
b = 56
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a56[j-i]
        b = b+80
    a = a+1
    b = 56
    
    
a = 0
b = 57
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a57[j-i]
        b = b+80
    a = a+1
    b = 57
    
a = 0
b = 58
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a58[j-i]
        b = b+80
    a = a+1
    b = 58
    
    
a = 0
b = 59
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a59[j-i]
        b = b+80
    a = a+1
    b = 59
    
    
    
a = 0
b = 60
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a60[j-i]
        b = b+80
    a = a+1
    b = 60
    

a = 0
b = 61
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a61[j-i]
        b = b+80
    a = a+1
    b = 61

    
a = 0
b = 62
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a62[j-i]
        b = b+80
    a = a+1
    b = 62


a = 0
b = 63
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a63[j-i]
        b = b+80
    a = a+1
    b = 63
    
    
a = 0
b = 64
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a64[j-i]
        b = b+80
    a = a+1
    b = 64

a = 0
b = 65
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a65[j-i]
        b = b+80
    a = a+1
    b = 65

    
a = 0
b = 66
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a66[j-i]
        b = b+80
    a = a+1
    b = 66

a = 0
b = 67
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a67[j-i]
        b = b+80
    a = a+1
    b = 67
    
a = 0
b = 68
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a68[j-i]
        b = b+80
    a = a+1
    b = 68
    

a = 0
b = 69
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a69[j-i]
        b = b+80
    a = a+1
    b = 69
    
a = 0
b = 70
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a70[j-i]
        b = b+80
    a = a+1
    b = 70

a = 0
b = 71
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a71[j-i]
        b = b+80
    a = a+1
    b = 71
    
    
a = 0
b = 72
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a72[j-i]
        b = b+80
    a = a+1
    b = 72
    
a = 0
b = 73
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a73[j-i]
        b = b+80
    a = a+1
    b = 73
    
    
a = 0
b = 74
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a74[j-i]
        b = b+80
    a = a+1
    b = 74
    
    
    
a = 0
b = 75
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a75[j-i]
        b = b+80
    a = a+1
    b = 75
    

a = 0
b = 76
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a76[j-i]
        b = b+80
    a = a+1
    b = 76

    
a = 0
b = 77
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a77[j-i]
        b = b+80
    a = a+1
    b = 77


a = 0
b = 78
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a78[j-i]
        b = b+80
    a = a+1
    b = 78
    
    
a = 0
b = 79
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a79[j-i]
        b = b+80
    a = a+1
    b = 79

a = 0
b = 80
for j in range(short,long):   
    for i in range(roll):
        df2.iloc[a,b]=a80[j-i]
        b = b+80
    a = a+1
    b = 80

    
df2 = df2.drop(columns='A0')  # 删除A0这一列 
df2.to_csv(file_400_Test,index = False)
print('Test file OK')


###########################################################################################
#复制训练集，加到测试的前面和后面，为了应对PCA降维

data_Train = pd.read_csv(file_400_Train)
data_Train = data_Train.drop('A0', axis=1)   ### 删除A0这列

data = pd.concat([data_Train, df2], ignore_index=True)
data = pd.concat([data, data_Train], ignore_index=True)

data.to_csv(file_400_Train_3,index = False)
print('Train + Test PCA file OK')


###########################################################################################
#如果标签9是26  8是27，7是28，6是29，5是30,15是20

file_name = file_400_Train
df_400 = pd.read_csv(file_name)

if df_400.iloc[0,22] == df_label.iloc[label,1]:   
    
    label_copy = df_label.loc[(label+1):(len(df_400)+label),'state']
    label_copy  = label_copy .reset_index(drop=True)
    df_400['A0'] = label_copy
    df_400.to_csv(file_400_Train,index = False)
    print('Label OK')
    
else:
    print('Label NG !!!')
# Out:
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:403: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0047325402697637' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a1[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:403: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0015397397143726' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a1[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:403: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0052271529508995' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a1[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:403: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0003234709770509' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a1[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:403: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0041752985826732' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a1[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:413: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-3.952247923422192e-05' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a2[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:413: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0002653741893006' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a2[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:413: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '4.669007303448325e-05' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a2[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:413: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-7.94420355170189e-05' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a2[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:413: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0003736962587037' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a2[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:423: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.2744082727065535' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a3[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:423: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.269929077233064' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a3[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:423: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.271023041957921' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a3[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:423: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.2759650813362375' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a3[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:423: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.275346558518223' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a3[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:433: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.2751664744938775' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a4[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:433: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.270403568766741' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a4[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:433: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.2716621284131575' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a4[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:433: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.27636832445017' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a4[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:433: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.276061064409968' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a4[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:442: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0031928005553911' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a5[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:442: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0067668926652721' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a5[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:442: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0049036819738486' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a5[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:442: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0038518276056223' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a5[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:442: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0093032491061482' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a5[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:451: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0049979144590643' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a6[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:451: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0014930496413381' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a6[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:451: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0053065949864166' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a6[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:451: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-5.022528165277152e-05' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a6[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:451: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0041794661710294' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a6[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.274661617502828' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a7[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.2694833022435486' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a7[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.270737928385338' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a7[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.275670029495274' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a7[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.274828833163324' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a7[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:469: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.275136109036505' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a8[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:469: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.270122388698785' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a8[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:469: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.27114117149927' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a8[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:469: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.276384535387019' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a8[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:469: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.2755320264787215' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a8[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:479: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0020343523955084' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a9[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:479: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0064434216882212' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a9[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:479: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0090789805565218' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a9[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:479: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0089797781290972' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a9[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:479: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0008166209929978' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a9[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:488: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0032394906284256' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a10[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:488: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0068463347007892' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a10[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:488: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0052773782325523' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a10[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:488: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0038559951939785' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a10[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:488: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0086414878091165' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a10[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:497: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.274215842513312' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a11[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:497: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.269198188670965' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a11[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:497: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.270442876544374' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a11[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:497: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.275152304140375' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a11[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:497: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.274905140736374' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a11[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:507: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.274854928968549' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a12[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:507: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.269601431784897' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a12[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:507: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.27115738243612' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a12[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:507: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.2758554974557725' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a12[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:507: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.276071264469172' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a12[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:516: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0017108814184574' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a13[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:516: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0106187202708945' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a13[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:516: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0142069310799968' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a13[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:516: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0004931500159468' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a13[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:516: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0016071578556697' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a13[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:526: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0021137944310254' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a14[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:526: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0068171179469249' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a14[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:526: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.009083148144878' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a14[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:526: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0083180168320655' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a14[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:526: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0010129812367303' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a14[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:537: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.273930728940729' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a15[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:537: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.268903136830001' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a15[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:537: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.269925151189475' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a15[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:537: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.275228611713425' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a15[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:537: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.275658352005368' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a15[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:547: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.274333972054661' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a16[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:547: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.269617642721747' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a16[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:547: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.270628344504873' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a16[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:547: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.276394735446223' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a16[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:547: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.276213962607443' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a16[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:557: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0058861800011307' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a17[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:557: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0157466707943694' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a17[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:557: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0057203029668464' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a17[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:557: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0019306288327207' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a17[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:557: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0030589185595957' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a17[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:567: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0020845776771611' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a18[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:567: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0106228878592506' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a18[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:567: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0135451697829651' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a18[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:567: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0006895102596793' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a18[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:567: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0014048527694061' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a18[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:577: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.273635677099765' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a19[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:577: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.268385411475102' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a19[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:577: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.2700014587625255' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a19[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:577: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.275981822982419' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a19[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:577: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.275271766643527' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a19[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:586: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.274350182991511' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a20[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:586: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.2690886047905' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a20[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:586: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.271167582495323' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a20[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:586: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.276537433584494' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a20[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:586: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.276683657675894' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a20[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:595: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0044342890996666' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a21[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:595: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0032323230346253' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a21[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:595: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0070322668545728' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a21[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:595: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.004950372046883' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a21[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:595: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0037723855701052' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a21[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:604: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0003377736493312' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a22[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:604: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0050374369382986' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a22[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:604: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0017584238306387' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a22[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:604: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.005353285059451' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a22[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:604: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2.921675386424738e-05' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a22[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:613: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.2741100215364565' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a23[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:613: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.274701139982062' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a23[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:613: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.269217928054248' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a23[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:613: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.270691238312304' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a23[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:613: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.275749471530791' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a23[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:623: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.2748682233237805' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a24[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:623: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.275175631515739' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a24[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:623: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.269857014509484' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a24[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:623: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.271094481426236' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a24[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:623: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.276463977422536' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a24[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:632: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.002894549385294' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a25[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:632: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0019948299162741' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a25[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:632: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0067087958775218' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a25[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:632: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0091256706295563' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a25[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:632: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0089003360935802' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a25[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:641: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0046996632889673' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a26[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:641: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0032790131076598' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a26[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:641: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0071117088900898' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a26[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:641: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0053240683055868' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a26[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:641: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0037765531584614' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a26[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:651: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.2743633663327305' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a27[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:651: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.2742553649925465' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a27[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:651: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.268932814481665' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a27[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:651: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.27039618647134' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a27[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:651: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.275231746175892' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a27[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:660: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.274837857866408' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a28[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:660: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.274894451447783' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a28[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:660: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.269336057595597' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a28[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:660: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.271110692363085' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a28[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:660: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.2759349394912896' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a28[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0023326035656054' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a29[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0016713589392232' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a29[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0108840944601951' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a29[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0142536211530313' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a29[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0004137079804298' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a29[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:681: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0029412394583285' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a30[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:681: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0020742719517912' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a30[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:681: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0070824921362255' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a30[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:681: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0091298382179125' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a30[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:681: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0082385747965485' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a30[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:692: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.273917591343215' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a31[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:692: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.273970251419963' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a31[j-i]
# ...
#   df2.iloc[a,b]=a70[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1969: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0006518404797373' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a71[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1969: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.000171552224939' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a71[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1969: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0003092525034378' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a71[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1969: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2.531849105924522e-05' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a71[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1969: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.000326500767819' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a71[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1979: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-8.332301837388201e-05' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a72[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1979: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0004533813640734' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a72[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1979: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0006485655034893' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a72[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1979: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0005944533052786' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a72[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1979: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0004082418521837' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a72[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1988: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.197609189557278' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a73[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1988: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.196458498892733' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a73[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1988: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.198097889353315' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a73[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1988: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.193333659088843' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a73[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1988: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.193970410930441' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a73[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1998: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.199038438838405' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a74[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1998: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.197589260337411' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a74[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1998: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.196293135311871' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a74[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1998: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.198607359309552' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a74[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:1998: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.193661012973707' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a74[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2009: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0003823519459635' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a75[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2009: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.000144207206433' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a75[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2009: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0003178404907147' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a75[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2009: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-5.961063962445223e-07' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a75[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2009: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0002344728552379' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a75[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2019: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0002425816430489' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a76[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2019: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0004835202064845' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a76[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2019: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.000886975304934' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a76[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2019: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0007341465136065' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a76[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2019: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0007764923536526' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a76[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2029: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.196669298613758' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a77[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2029: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.19826293465032' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a77[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2029: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.193041137089187' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a77[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2029: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.193644506269019' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a77[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2029: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.199147673147961' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a77[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2039: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.197800060058436' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a78[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2039: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.196458180608875' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a78[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2039: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.198314837309896' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a78[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2039: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.193335108312285' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a78[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2039: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.194179945551967' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a78[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2049: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6.65925145915125e-05' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a79[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2049: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0001527951937099' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a79[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2049: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0002919258932592' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a79[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2049: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0005603775166607' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a79[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2049: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.0005268309785617' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a79[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2058: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.00027272048546' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a80[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2058: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0007219300079293' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a80[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2058: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.001026668513262' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a80[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2058: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0011023970150754' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a80[j-i]
# C:\Users\pld\AppData\Local\Temp\ipykernel_5212\3615827433.py:2058: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0003996708901548' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df2.iloc[a,b]=a80[j-i]
# Test file OK
# Train + Test PCA file OK
# Label OK

# %%
file_400_Train_3
# Out:
# 'E:/dragon/GA_Shane/outputs/20250410_handmade\\RB99_1m_output_axis.csv_tz80_Test_6355_PCA.csv'
